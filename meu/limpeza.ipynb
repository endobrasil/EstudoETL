# %%
import pandas as pd
import pandera as pa

# %%
df=pd.read_csv("ocorrencia_2010_2020.csv",sep=',',parse_dates=['ocorrencia_dia'])
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes Unnamed: 9 Unnamed: 10
# 0        12:00:00                   0        NaN         NaN
# ...

# %%
#peda os dados de uma linha e coluna
df.loc[0,'ocorrencia_cidade']
# Out:
# 'RIO DE JANEIRO'

# %%
#da linha 1 ae a três
#df.loc[:] aqui pega todas as linhas
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
#
#   ocorrencia_hora total_recomendacoes Unnamed: 9 Unnamed: 10
# 1        11:05:00                   0        NaN         NaN
# 2        03:00:00                   0        NaN         NaN
# 3        17:30:00                   0        NaN         NaN

# %%
#saber se a coluna tem valor único 
# exemplo este retorna false 
#df.ocorrencia_uf.is_unique
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
#define uma coluna como chave primária
df.set_index('codigo_ocorrencia',inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora total_recomendacoes  \
# codigo_ocorrencia
# ...

# %%
#como agora ele possui um indice é apartir deste que busco os dados
df.loc[40324]
# Out:
# codigo_ocorrencia2               40324
# ocorrencia_classificacao     INCIDENTE
# ocorrencia_cidade              PELOTAS
# ocorrencia_uf                       RS
# ocorrencia_aerodromo              SBPK
# ocorrencia_dia              05/01/2010
# ocorrencia_hora               19:25:00
# total_recomendacoes                  0
# Unnamed: 9                         NaN
# Unnamed: 10                        NaN
# Name: 40324, dtype: object

# %%
#ai se eu quero resetar o indice 
#e voltar pro que era antes
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     03/01/2010        12:00:00
# 1            PA                 SBBE     03/01/2010        11:05:00
# 2            RJ                 SBRJ     03/01/2010        03:00:00
# 3            MT                 ****     04/01/2010        17:30:00
# 4            RS                 SBPK     05/01/2010        19:25:00
#
#   total_recomendacoes Unnamed: 9 Unnamed: 10
# 0                   0        NaN         NaN
# 1                   0        NaN         NaN
# ...

# %%
#onde existe 4 * ser passado para vazio
df.loc[:,'ocorrencia_aerodromo']=''
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
#
#   total_recomendacoes Unnamed: 9 Unnamed: 10
# 0                   0        NaN         NaN

# %%
#alterar os dados de uma linha
df.loc[1]=20
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#   total_recomendacoes Unnamed: 9 Unnamed: 10
# 0                   0        NaN         NaN
# 1                  20         20          20
# ...

# %%
#alterar os dados de uma coluna
df.loc[:,'total_recomendacoes']=20
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10
# 0                   20        NaN         NaN
# 1                   20         20          20
# ...

# %%
#fazer um backup antes de tudo
df['ocorrencia_bk'] = df.ocorrencia_uf
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
#coluna ocorrencia classificação para grave
#onde a coluna uf for sp
df.loc[df.ocorrencia_uf=='SP', ['ocorrencia_classificacao']]='grave'

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %% [raw]
# linpar estes tipós de dados
# ocorrencia_uf
# ***
# 890274583
# 87
# 82439
# 6372222
# 6530
# 1408920
# 4780
# 13666
# 3705
# 25234
# 37
#
# ocorrencia_aerodromo
# ****
# *****
# ####
# ###!
# ocorrencia_hora
# NULL

# %%
#onde existir 4 * na linha ele substitui por NA que é algo pŕoprio da biblioteca panda
# NA => not avaliable
df.loc[df.ocorrencia_aerodromo=='****',['ocorrencia_aerodromo']]=pd.NA
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
#mas caso eu queira fazer tudod e uma vez existe o raplace...
df.replace(['***','NULL','890274583','87','82439','6372222'],pd.NA, inplace=True)
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
# ai com a marcação dos dados não informados NA
# consigo fazer uma busca quem são estes
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  5
# ocorrencia_aerodromo           0
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# Unnamed: 9                  5739
# Unnamed: 10                 5740
# ocorrencia_bk                  5
# dtype: int64

# %%
#aqui eu coloco um valor 
#quando marcado com dado não informado
df.fillna(0)
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    grave            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE                 -43
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
#excluindo uma coluna que criei no meu data frame
df['total_recomendacoes_bk']=df.total_recomendacoes
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk  \
# 0                   20        NaN         NaN            RJ
# ...

# %%
df.drop(['total_recomendacoes_bk'],axis=1, inplace=True) #axis 1 = eixo da coluna
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
#exluir todos os valores não informados
df.dropna()
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
#exluir todos os valores não informados em uma coluna
df.dropna(subset=['ocorrencia_uf'])
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
# 2            RJ                          03/01/2010        03:00:00
# 3            MT                          04/01/2010        17:30:00
# 4            RS                          05/01/2010        19:25:00
#
#    total_recomendacoes Unnamed: 9 Unnamed: 10 ocorrencia_bk
# 0                   20        NaN         NaN            RJ
# ...

# %%
#excluir os valores duplicados
df.drop_duplicates()
df.head()
